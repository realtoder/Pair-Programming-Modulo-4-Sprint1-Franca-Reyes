# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# %%
data = pd.read_csv('drug_consumption.csv')
data.sample(5)
# Out:
#       Unnamed: 0    ID      Age  Gender  \
# 413          413   416  35 - 44  Female
# 272          272   273  55 - 64    Male
# 1144        1144  1148  25 - 34    Male
# 816          816   820  25 - 34  Female
# 225          225   226  35 - 44  Female
#
#                                   Education Country Ethnicity   Nscore  \
# 413   Some College,No Certificate Or Degree      UK     White -1.86962
# 272                        Doctorate Degree      UK     White -1.05308
# 1144                      University Degree     USA     White -2.75696
# 816                          Masters Degree      UK     White  1.60383
# 225                       University Degree      UK     White -1.32828
#
#        Escore   Oscore   Ascore   Cscore  Impulsive       SS  \
# 413   0.32197 -1.11902 -0.15487 -0.65253    0.19268 -0.21575
# 272   0.00332 -0.01928  0.28783 -0.00665    0.52975 -0.84637
# 1144 -0.43999 -1.11902 -1.47955  0.93949   -0.21712  0.07987
# ...

# %%
#Creamos la función para explorar los datos. 

def exploracion_datos(df):
    print('_____________ INFORMACIÓN GENERAL DEL DATAFRAME ____________\n')
    print(df.info())

    print('___________________ FORMA DEL DATAFRAME ____________________\n')
    
    print(f"El número de filas que tenemos es de {df.shape[0]}.\nEl número de columnas es de {df.shape[1]}\n")
    

    print('_______________ NULOS, ÚNICOS Y DUPLICADOS _________________\n')
    
    print('La cantidad de valores NULOS por columna es de:\n')
    print(df.isnull().sum())
    print('____________________________________________________________\n')

    print('La cantidad de valores ÚNICOS por columna es de:\n')
        
    for columna in df.columns:
        cantidad_valores_unicos = len(df[columna].unique())
    
        print(f'La columna {columna}: {cantidad_valores_unicos}')

    """ Otra forma más rápida de obtener la lista de valores únicos por columna es usando df.nunique()"""

    print('____________________________________________________________\n')

    print('La cantidad de valores DUPLICADOS por columna es de:\n')

    """En análisis posteriores hemos detectado que hay columnas con valores duplicados que nos interesa filtrar, 
    así que vamos a realizar otro bucle for para iterar por todas las columnas del DF y obtener los duplicados de cada una de ellas."""

    for columna in df.columns:
        cantidad_duplicados = df[columna].duplicated().sum()
    
        print(f'La columna {columna}: {cantidad_duplicados}')


    print('____________________ RESUMEN ESTADÍSTICO ____________________')
    print('____________________ Variables Numéricas __________________\n')
    print(df.describe().T)
    
    print('___________________ Variables Categóricas _________________\n')
    print(df.describe(include='object').T)

# %%
exploracion_datos(data)
# Out:
# _____________ INFORMACIÓN GENERAL DEL DATAFRAME ____________
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1885 entries, 0 to 1884
# Data columns (total 32 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         1885 non-null   int64
#  1   Age        1885 non-null   float64
#  2   Gender     1885 non-null   float64
#  3   Education  1885 non-null   float64
#  4   Country    1885 non-null   float64
#  5   Ethnicity  1885 non-null   float64
#  6   Nscore     1885 non-null   float64
#  7   Escore     1885 non-null   float64
#  8   Oscore     1885 non-null   float64
#  9   Ascore     1885 non-null   float64
#  10  Cscore     1885 non-null   float64
#  11  Impulsive  1885 non-null   float64
#  12  SS         1885 non-null   float64
#  13  Alcohol    1885 non-null   object
#  14  Amphet     1885 non-null   object
#  15  Amyl       1885 non-null   object
#  16  Benzos     1885 non-null   object
# ...

# %% [markdown]
# Cambiar los valores a unos más intuitivos

# %%
age_col = {
          -0.95197: '18-24',
          -0.07854: '25 - 34',
          0.49788: '35 - 44',
          1.09449: '45 - 54',
          1.82213: '55 - 64',
          2.59171: '65+'
          }
data['Age'] = data['Age'].replace(age_col)

# %%
data.head()
# Out:
#    ID      Age   Gender  Education  Country  Ethnicity   Nscore   Escore  \
# 0   1  35 - 44  0.48246   -0.05921  0.96082    0.12600  0.31287 -0.57545
# 1   2  25 - 34 -0.48246    1.98437  0.96082   -0.31685 -0.67825  1.93886
# 2   3  35 - 44 -0.48246   -0.05921  0.96082   -0.31685 -0.46725  0.80523
# 3   4    18-24  0.48246    1.16365  0.96082   -0.31685 -0.14882 -0.80615
# 4   5  35 - 44  0.48246    1.98437  0.96082   -0.31685  0.73545 -1.63340
#
#     Oscore   Ascore   Cscore  Impulsive       SS Alcohol Amphet Amyl Benzos  \
# 0 -0.58331 -0.91699 -0.00665   -0.21712 -1.18084     CL5    CL2  CL0    CL2
# 1  1.43533  0.76096 -0.14277   -0.71126 -0.21575     CL5    CL2  CL2    CL0
# 2 -0.84732 -1.62090 -1.01450   -1.37983  0.40148     CL6    CL0  CL0    CL0
# 3 -0.01928  0.59042  0.58489   -1.37983 -1.18084     CL4    CL0  CL0    CL3
# 4 -0.45174 -0.30172  1.30612   -0.21712 -0.21575     CL4    CL1  CL1    CL0
#
# ...

# %%
gender_col = {
            0.48246: 'Female',
            -0.48246: 'Male'
            }
data['Gender'] = data['Gender'].replace(gender_col)

# %%
data
# Out:
#         ID      Age  Gender  Education  Country  Ethnicity   Nscore   Escore  \
# 0        1  35 - 44  Female   -0.05921  0.96082    0.12600  0.31287 -0.57545
# 1        2  25 - 34    Male    1.98437  0.96082   -0.31685 -0.67825  1.93886
# 2        3  35 - 44    Male   -0.05921  0.96082   -0.31685 -0.46725  0.80523
# 3        4    18-24  Female    1.16365  0.96082   -0.31685 -0.14882 -0.80615
# 4        5  35 - 44  Female    1.98437  0.96082   -0.31685  0.73545 -1.63340
# ...    ...      ...     ...        ...      ...        ...      ...      ...
# 1880  1884    18-24  Female   -0.61113 -0.57009   -0.31685 -1.19430  1.74091
# 1881  1885    18-24    Male   -0.61113 -0.57009   -0.31685 -0.24649  1.74091
# 1882  1886  25 - 34  Female    0.45468 -0.57009   -0.31685  1.13281 -1.37639
# 1883  1887    18-24  Female   -0.61113 -0.57009   -0.31685  0.91093 -1.92173
# 1884  1888    18-24    Male   -0.61113  0.21128   -0.31685 -0.46725  2.12700
#
# ...

# %%
education_col = {
            -2.43591: 'Left School Before 16 years',
            -1.73790: 'Left School at 16 years',
            -1.43719: 'Left School at 17 years',
            -1.22751: 'Left School at 18 years',
            -0.61113: 'Some College,No Certificate Or Degree',
            -0.05921: 'Professional Certificate/ Diploma',
            0.45468: 'University Degree',
            1.16365: 'Masters Degree',
            1.98437: 'Doctorate Degree',
            }
data['Education'] = data['Education'].replace(education_col)

# %%
data
# Out:
#         ID      Age  Gender                              Education  Country  \
# 0        1  35 - 44  Female      Professional Certificate/ Diploma  0.96082
# 1        2  25 - 34    Male                       Doctorate Degree  0.96082
# 2        3  35 - 44    Male      Professional Certificate/ Diploma  0.96082
# 3        4    18-24  Female                         Masters Degree  0.96082
# 4        5  35 - 44  Female                       Doctorate Degree  0.96082
# ...    ...      ...     ...                                    ...      ...
# 1880  1884    18-24  Female  Some College,No Certificate Or Degree -0.57009
# 1881  1885    18-24    Male  Some College,No Certificate Or Degree -0.57009
# 1882  1886  25 - 34  Female                      University Degree -0.57009
# 1883  1887    18-24  Female  Some College,No Certificate Or Degree -0.57009
# 1884  1888    18-24    Male  Some College,No Certificate Or Degree  0.21128
#
# ...

# %%
country_col = {
            -0.09765: 'Australia',
            0.24923: 'Canada',
            -0.46841: 'New Zealand',
            -0.28519: 'Other',
            0.21128: 'Republic of Ireland',
            0.96082: 'UK',
            -0.57009: 'USA'
            }
data['Country'] = data['Country'].replace(country_col)

# %%
data
# Out:
#         ID      Age  Gender                              Education  \
# 0        1  35 - 44  Female      Professional Certificate/ Diploma
# 1        2  25 - 34    Male                       Doctorate Degree
# 2        3  35 - 44    Male      Professional Certificate/ Diploma
# 3        4    18-24  Female                         Masters Degree
# 4        5  35 - 44  Female                       Doctorate Degree
# ...    ...      ...     ...                                    ...
# 1880  1884    18-24  Female  Some College,No Certificate Or Degree
# 1881  1885    18-24    Male  Some College,No Certificate Or Degree
# 1882  1886  25 - 34  Female                      University Degree
# 1883  1887    18-24  Female  Some College,No Certificate Or Degree
# 1884  1888    18-24    Male  Some College,No Certificate Or Degree
#
#                   Country  Ethnicity   Nscore   Escore   Oscore   Ascore  \
# 0                      UK    0.12600  0.31287 -0.57545 -0.58331 -0.91699
# ...

# %%
ethnicity_col = {
            -0.50212: 'Asian',
            -1.10702: 'Black',
            1.90725: 'Mixed-Black/Asian',
            0.12600: 'Mixed-White/Asian',
            -0.22166: 'Mixed-White/Black',
            0.11440: 'Other',
            -0.31685: 'White'
            }
data['Ethnicity'] = data['Ethnicity'].replace(ethnicity_col)

# %%
data
# Out:
#         ID      Age  Gender                              Education  \
# 0        1  35 - 44  Female      Professional Certificate/ Diploma
# 1        2  25 - 34    Male                       Doctorate Degree
# 2        3  35 - 44    Male      Professional Certificate/ Diploma
# 3        4    18-24  Female                         Masters Degree
# 4        5  35 - 44  Female                       Doctorate Degree
# ...    ...      ...     ...                                    ...
# 1880  1884    18-24  Female  Some College,No Certificate Or Degree
# 1881  1885    18-24    Male  Some College,No Certificate Or Degree
# 1882  1886  25 - 34  Female                      University Degree
# 1883  1887    18-24  Female  Some College,No Certificate Or Degree
# 1884  1888    18-24    Male  Some College,No Certificate Or Degree
#
#                   Country          Ethnicity   Nscore   Escore   Oscore  \
# 0                      UK  Mixed-White/Asian  0.31287 -0.57545 -0.58331
# ...

# %%
usage_col = {
    'CL0': 'Never Used',
    'CL1': 'Used over a Decade Ago',
    'CL2': 'Used in Last Decade',
    'CL3': 'Used in Last Year',
    'CL4': 'Used in Last Month',
    'CL5': 'Used in Last Week',
    'CL6': 'Used in Last Day',
    }
data['Alcohol'] = data['Alcohol'].replace(usage_col)
data['Amphet'] = data['Amphet'].replace(usage_col)
data['Amyl'] = data['Amyl'].replace(usage_col)
data['Benzos'] = data['Benzos'].replace(usage_col)
data['Caff'] = data['Caff'].replace(usage_col)
data['Cannabis'] = data['Cannabis'].replace(usage_col)
data['Choc'] = data['Choc'].replace(usage_col)
data['Coke'] = data['Coke'].replace(usage_col)
data['Crack'] = data['Crack'].replace(usage_col)
data['Ecstasy'] = data['Ecstasy'].replace(usage_col)
data['Heroin'] = data['Heroin'].replace(usage_col)
data['Ketamine'] = data['Ketamine'].replace(usage_col)
data['Legalh'] = data['Legalh'].replace(usage_col)
data['LSD'] = data['LSD'].replace(usage_col)
data['Meth'] = data['Meth'].replace(usage_col)
data['Mushrooms'] = data['Mushrooms'].replace(usage_col)
data['Nicotine'] = data['Nicotine'].replace(usage_col)
data['Semer'] = data['Semer'].replace(usage_col)
data['VSA'] = data['VSA'].replace(usage_col)

# %%
data.head(5)
# Out:
#    ID      Age  Gender                          Education Country  \
# 0   1  35 - 44  Female  Professional Certificate/ Diploma      UK
# 1   2  25 - 34    Male                   Doctorate Degree      UK
# 2   3  35 - 44    Male  Professional Certificate/ Diploma      UK
# 3   4    18-24  Female                     Masters Degree      UK
# 4   5  35 - 44  Female                   Doctorate Degree      UK
#
#            Ethnicity   Nscore   Escore   Oscore   Ascore   Cscore  Impulsive  \
# 0  Mixed-White/Asian  0.31287 -0.57545 -0.58331 -0.91699 -0.00665   -0.21712
# 1              White -0.67825  1.93886  1.43533  0.76096 -0.14277   -0.71126
# 2              White -0.46725  0.80523 -0.84732 -1.62090 -1.01450   -1.37983
# 3              White -0.14882 -0.80615 -0.01928  0.59042  0.58489   -1.37983
# 4              White  0.73545 -1.63340 -0.45174 -0.30172  1.30612   -0.21712
#
#         SS             Alcohol                  Amphet  \
# ...

# %%
data.to_csv("drug_consumption.csv")
data.head()
# Out:
#    ID      Age  Gender                          Education Country  \
# 0   1  35 - 44  Female  Professional Certificate/ Diploma      UK
# 1   2  25 - 34    Male                   Doctorate Degree      UK
# 2   3  35 - 44    Male  Professional Certificate/ Diploma      UK
# 3   4    18-24  Female                     Masters Degree      UK
# 4   5  35 - 44  Female                   Doctorate Degree      UK
#
#            Ethnicity   Nscore   Escore   Oscore   Ascore   Cscore  Impulsive  \
# 0  Mixed-White/Asian  0.31287 -0.57545 -0.58331 -0.91699 -0.00665   -0.21712
# 1              White -0.67825  1.93886  1.43533  0.76096 -0.14277   -0.71126
# 2              White -0.46725  0.80523 -0.84732 -1.62090 -1.01450   -1.37983
# 3              White -0.14882 -0.80615 -0.01928  0.59042  0.58489   -1.37983
# 4              White  0.73545 -1.63340 -0.45174 -0.30172  1.30612   -0.21712
#
#         SS             Alcohol                  Amphet  \
# ...

# %%
# Redondear los valores a 2 lugares decimales
data[['Nscore', 'Escore', 'Oscore', 'Ascore', 'Cscore']] = data[['Nscore', 'Escore', 'Oscore', 'Ascore', 'Cscore']].round(2)

# %%
data.head(5)
# Out:
#    Unnamed: 0  ID      Age  Gender                          Education Country  \
# 0           0   1  35 - 44  Female  Professional Certificate/ Diploma      UK
# 1           1   2  25 - 34    Male                   Doctorate Degree      UK
# 2           2   3  35 - 44    Male  Professional Certificate/ Diploma      UK
# 3           3   4    18-24  Female                     Masters Degree      UK
# 4           4   5  35 - 44  Female                   Doctorate Degree      UK
#
#            Ethnicity  Nscore  Escore  Oscore  Ascore  Cscore  Impulsive  \
# 0  Mixed-White/Asian    0.31   -0.58   -0.58   -0.92   -0.01   -0.21712
# 1              White   -0.68    1.94    1.44    0.76   -0.14   -0.71126
# 2              White   -0.47    0.81   -0.85   -1.62   -1.01   -1.37983
# 3              White   -0.15   -0.81   -0.02    0.59    0.58   -1.37983
# 4              White    0.74   -1.63   -0.45   -0.30    1.31   -0.21712
#
#         SS             Alcohol                  Amphet  \
# ...

# %% [markdown]
# nscore
#
# 10 - 28 : bajo -- -3.46 a -1.32
# 29 - 44: medio -- -1.19 a -0.05
# 45 - 60: alto -- 0.04

# %%
# Definir una función para categorizar los valores
def categorize_nscore(value):
    if -3.46 <= value <= -1.32:
        return 'bajo'
    elif -1.31 <= value <= -0.05:
        return 'medio'
    elif -0.04 <= value <= 3.26:
        return 'alto'


# Aplicar la función a la columna 'Nscore'
data['Nscore'] = data['Nscore'].apply(categorize_nscore)

# %%
# Definir una función para categorizar los valores
def categorize_nscore(value):
    if -3.27 <= value <= -1.51:
        return 'bajo'
    elif -1.50 <= value <= 0.47:
        return 'medio'
    elif 0.48 <= value <= 3.27:
        return 'alto'


# Aplicar la función a la columna 'Nscore'
data['Escore'] = data['Escore'].apply(categorize_nscore)

# %%
data['Escore'].value_counts()
# Out:
# Escore
# medio    1095
# alto      650
# bajo      140
# Name: count, dtype: int64

# %%
# Definir una función para categorizar los valores
def categorize_nscore(value):
    if -3.27 <= value <= -1.55:
        return 'bajo'
    elif -1.54 <= value <= 0.29:
        return 'medio'
    elif 0.30 <= value <= 2.90:
        return 'alto'


# Aplicar la función a la columna 'Nscore'
data['Oscore'] = data['Oscore'].apply(categorize_nscore)

# %%
data['Oscore'].value_counts()
# Out:
# Oscore
# medio    1092
# alto      667
# bajo      126
# Name: count, dtype: int64

# %%
# Definir una función para categorizar los valores
def categorize_nscore(value):
    if -3.46 <= value <= -2.35:
        return 'bajo'
    elif -2.34 <= value <= -0.02:
        return 'medio'
    elif -0.01 <= value <= 3.46:
        return 'alto'


# Aplicar la función a la columna 'Nscore'
data['Ascore'] = data['Ascore'].apply(categorize_nscore)

# %%
data['Ascore'].value_counts()
# Out:
# Ascore
# medio    961
# alto     903
# bajo      21
# Name: count, dtype: int64

# %%
# Definir una función para categorizar los valores
def categorize_nscore(value):
    if -3.46 <= value <= -1.52:
        return 'bajo'
    elif -1.51 <= value <= -0.26:
        return 'medio'
    elif -0.25 <= value <= 3.46:
        return 'alto'


# Aplicar la función a la columna 'Nscore'
data['Cscore'] = data['Cscore'].apply(categorize_nscore)

# %%
data['Cscore'].value_counts()
# Out:
# Cscore
# alto     1099
# medio     650
# bajo      136
# Name: count, dtype: int64

# %%
data.to_csv("drug_consumption.csv")
data.head()
# Out:
#    Unnamed: 0  ID      Age  Gender                          Education Country  \
# 0           0   1  35 - 44  Female  Professional Certificate/ Diploma      UK
# 1           1   2  25 - 34    Male                   Doctorate Degree      UK
# 2           2   3  35 - 44    Male  Professional Certificate/ Diploma      UK
# 3           3   4    18-24  Female                     Masters Degree      UK
# 4           4   5  35 - 44  Female                   Doctorate Degree      UK
#
#            Ethnicity Nscore Escore Oscore Ascore Cscore  Impulsive       SS  \
# 0  Mixed-White/Asian   alto  medio  medio  medio   alto   -0.21712 -1.18084
# 1              White  medio   alto   alto   alto   alto   -0.71126 -0.21575
# 2              White  medio   alto  medio  medio  medio   -1.37983  0.40148
# 3              White  medio  medio  medio   alto   alto   -1.37983 -1.18084
# 4              White   alto   bajo  medio  medio   alto   -0.21712 -0.21575
#
# ...

# %%
data.drop(columns=['Impulsive', 'SS'], inplace= True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[115], line 1
# ----> 1 data.drop(columns=['Impulsive', 'SS', 'Unnamed: 0'], inplace= True)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/frame.py:5347, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5199 def drop(
#    5200     self,
#    5201     labels: IndexLabel | None = None,
#    (...)
#    5208     errors: IgnoreRaise = "raise",
#    5209 ) -> DataFrame | None:
#    5210     """
#    5211     Drop specified labels from rows or columns.
#    5212
#    (...)
#    5345             weight  1.0     0.8
#    5346     """
# -> 5347     return super().drop(
#    5348         labels=labels,
#    5349         axis=axis,
#    5350         index=index,
#    5351         columns=columns,
#    5352         level=level,
#    5353         inplace=inplace,
# ...

# %%
data.drop(columns=['Unnamed: 0'], inplace= True)

# %%
data.head()
# Out:
#    ID      Age  Gender                          Education Country  \
# 0   1  35 - 44  Female  Professional Certificate/ Diploma      UK
# 1   2  25 - 34    Male                   Doctorate Degree      UK
# 2   3  35 - 44    Male  Professional Certificate/ Diploma      UK
# 3   4    18-24  Female                     Masters Degree      UK
# 4   5  35 - 44  Female                   Doctorate Degree      UK
#
#            Ethnicity Nscore Escore Oscore Ascore Cscore             Alcohol  \
# 0  Mixed-White/Asian   alto  medio  medio  medio   alto   Used in Last Week
# 1              White  medio   alto   alto   alto   alto   Used in Last Week
# 2              White  medio   alto  medio  medio  medio    Used in Last Day
# 3              White  medio  medio  medio   alto   alto  Used in Last Month
# 4              White   alto   bajo  medio  medio   alto  Used in Last Month
#
#                    Amphet                    Amyl               Benzos  \
# ...

# %%
data.to_csv("drug_consumption.csv", index = 0)
data.head()
# Out:
#    ID      Age  Gender                          Education Country  \
# 0   1  35 - 44  Female  Professional Certificate/ Diploma      UK
# 1   2  25 - 34    Male                   Doctorate Degree      UK
# 2   3  35 - 44    Male  Professional Certificate/ Diploma      UK
# 3   4    18-24  Female                     Masters Degree      UK
# 4   5  35 - 44  Female                   Doctorate Degree      UK
#
#            Ethnicity Nscore Escore Oscore Ascore Cscore             Alcohol  \
# 0  Mixed-White/Asian   alto  medio  medio  medio   alto   Used in Last Week
# 1              White  medio   alto   alto   alto   alto   Used in Last Week
# 2              White  medio   alto  medio  medio  medio    Used in Last Day
# 3              White  medio  medio  medio   alto   alto  Used in Last Month
# 4              White   alto   bajo  medio  medio   alto  Used in Last Month
#
#                    Amphet                    Amyl               Benzos  \
# ...

# %%
data['Semer'].value_counts()
# Out:
# Semer
# Never Used                1877
# Used in Last Decade          3
# Used in Last Year            2
# Used over a Decade Ago       2
# Used in Last Month           1
# Name: count, dtype: int64

# %%
data.groupby('Amphet')['ID'].count().reset_index()
# Out:
#                    Amphet   ID
# 0              Never Used  976
# 1        Used in Last Day  102
# 2     Used in Last Decade  243
# 3      Used in Last Month   75
# 4       Used in Last Week   61
# 5       Used in Last Year  198
# 6  Used over a Decade Ago  230
